# %%
import pandas as pd

# %%
df = pd.read_excel("NBA Stats 202122 All Player Metrics in one Page dec 11 2021.xlsx")
df.head()
# Out:
#            FULL NAME TEAM  POS  GP   MPG  USG%  FGA       FG%  FTA    FT%  \
# 0   Precious Achiuwa  Tor    F  21  26.5  17.2  184  0.385783   35  0.543
# 1       Steven Adams  Mem    C  26  25.1  13.4  127  0.520000   82  0.610
# 2        Bam Adebayo  Mia  C-F  18  32.9  25.9  243  0.518856  112  0.759
# 3       Santi Aldama  Mem  F-C  14  10.4  20.7   63  0.349286   10  0.600
# 4  LaMarcus Aldridge  Bro  C-F  24  23.6  22.2  252  0.575079   42  0.810
#
#    ...     3PM      3PPG   PPG   RPG  TRB%  APG   SPG   BPG    TO   DRTG
# 0  ...   6.994  0.333048   8.0   8.2  16.8  1.6  0.52  0.57  1.10  101.3
# 1  ...   0.000  0.000000   7.0   8.7  18.6  2.7  0.85  0.69  1.73  106.6
# 2  ...   0.000  0.000000  18.7  10.2  17.4  3.2  1.11  0.33  2.94   96.8
# 3  ...   2.997  0.214071   3.8   2.9  14.7  0.9  0.14  0.21  0.29  105.1
# 4  ...  10.005  0.416875  13.9   5.7  12.8  0.9  0.42  1.17  0.63  102.9
#
# [5 rows x 25 columns]

# %%
df1 = df.loc[[218,72,13,34,132,307,458,60,434,429,343,213,330,361]]
df1
# Out:
#                FULL NAME TEAM  POS  GP   MPG  USG%  FGA       FG%  FTA    FT%  \
# 218       Reggie Jackson  Lac    G  26  33.5  25.6  437  0.389144   47  0.787
# 72            Alec Burks  Nyk    G  26  25.3  18.6  225  0.404573   76  0.816
# 13          Cole Anthony  Orl    G  20  34.0  26.8  331  0.428713   77  0.870
# 34          Bradley Beal  Was    G  23  36.0  31.0  449  0.441038  105  0.848
# 132          Joel Embiid  Phi  C-F  16  32.9  33.1  272  0.441088  161  0.776
# 307          Evan Mobley  Cle    C  23  33.4  19.0  263  0.479213   69  0.783
# 458  Robert Williams III  Bos  C-F  20  27.5  11.7  108  0.741000   33  0.667
# 60       Malcolm Brogdon  Ind    G  23  35.5  24.8  364  0.447423  103  0.874
# 434    Jarred Vanderbilt  Min    F  25  23.5  10.8  112  0.535429   32  0.813
# 429       Gary Trent Jr.  Tor  G-F  24  34.6  20.3  351  0.430407   44  0.909
# 343      Kelly Oubre Jr.  Cha  F-G  28  29.3  22.6  382  0.463380   57  0.649
# ...

# %%
df1.drop(columns = ['USG%','FGA','FTA','2PA','2P%','2PM','3PA','3PM','TRB%','DRTG'])
# Out:
#                FULL NAME TEAM  POS  GP   MPG       FG%    FT%    3P%  \
# 218       Reggie Jackson  Lac    G  26  33.5  0.389144  0.787  0.326
# 72            Alec Burks  Nyk    G  26  25.3  0.404573  0.816  0.415
# 13          Cole Anthony  Orl    G  20  34.0  0.428713  0.870  0.364
# 34          Bradley Beal  Was    G  23  36.0  0.441038  0.848  0.262
# 132          Joel Embiid  Phi  C-F  16  32.9  0.441088  0.776  0.396
# 307          Evan Mobley  Cle    C  23  33.4  0.479213  0.783  0.333
# 458  Robert Williams III  Bos  C-F  20  27.5  0.741000  0.667  0.000
# 60       Malcolm Brogdon  Ind    G  23  35.5  0.447423  0.874  0.304
# 434    Jarred Vanderbilt  Min    F  25  23.5  0.535429  0.813  0.125
# 429       Gary Trent Jr.  Tor  G-F  24  34.6  0.430407  0.909  0.384
# 343      Kelly Oubre Jr.  Cha  F-G  28  29.3  0.463380  0.649  0.386
# 213       Brandon Ingram  Nor    F  21  35.0  0.446689  0.857  0.371
# 330         Jusuf Nurkic  Por    C  26  24.8  0.576182  0.745  0.238
# ...

# %%
last_row = {'FULL NAME': 'Team Stats', 'FG%': df1['FG%'].mean(), 'FT%': df1['FT%'].mean(), '3P%': df1['3P%'].mean(), 
       '3PPG': df1['3PPG'].sum(), 'PPG': df1['PPG'].sum(), 'RPG': df1['RPG'].sum(),'APG': df1['APG'].sum(), 
       'SPG': df1['SPG'].sum(), 'BPG': df1['BPG'].sum(), 'TO': df1['TO'].sum()}

df1 = df1.append(last_row, ignore_index = True)

df1
# Out:
#               FULL NAME TEAM  POS    GP   MPG  USG%    FGA       FG%    FTA  \
# 0        Reggie Jackson  Lac    G  26.0  33.5  25.6  437.0  0.389144   47.0
# 1            Alec Burks  Nyk    G  26.0  25.3  18.6  225.0  0.404573   76.0
# 2          Cole Anthony  Orl    G  20.0  34.0  26.8  331.0  0.428713   77.0
# 3          Bradley Beal  Was    G  23.0  36.0  31.0  449.0  0.441038  105.0
# 4           Joel Embiid  Phi  C-F  16.0  32.9  33.1  272.0  0.441088  161.0
# 5           Evan Mobley  Cle    C  23.0  33.4  19.0  263.0  0.479213   69.0
# 6   Robert Williams III  Bos  C-F  20.0  27.5  11.7  108.0  0.741000   33.0
# 7       Malcolm Brogdon  Ind    G  23.0  35.5  24.8  364.0  0.447423  103.0
# 8     Jarred Vanderbilt  Min    F  25.0  23.5  10.8  112.0  0.535429   32.0
# 9        Gary Trent Jr.  Tor  G-F  24.0  34.6  20.3  351.0  0.430407   44.0
# 10      Kelly Oubre Jr.  Cha  F-G  28.0  29.3  22.6  382.0  0.463380   57.0
# ...

# %%
Farzan = df1.drop(columns = ['USG%','FGA','FTA','2PA','2P%','2PM','3P%','3PA','3PM','TRB%','DRTG'])
Farzan
# Out:
#               FULL NAME TEAM  POS    GP   MPG       FG%       FT%       3PPG  \
# 0        Reggie Jackson  Lac    G  26.0  33.5  0.389144  0.787000   2.733385
# 1            Alec Burks  Nyk    G  26.0  25.3  0.404573  0.816000   1.963269
# 2          Cole Anthony  Orl    G  20.0  34.0  0.428713  0.870000   2.748200
# 3          Bradley Beal  Was    G  23.0  36.0  0.441038  0.848000   1.480870
# 4           Joel Embiid  Phi  C-F  16.0  32.9  0.441088  0.776000   1.311750
# 5           Evan Mobley  Cle    C  23.0  33.4  0.479213  0.783000   0.608087
# 6   Robert Williams III  Bos  C-F  20.0  27.5  0.741000  0.667000   0.000000
# 7       Malcolm Brogdon  Ind    G  23.0  35.5  0.447423  0.874000   1.824000
# 8     Jarred Vanderbilt  Min    F  25.0  23.5  0.535429  0.813000   0.040000
# 9        Gary Trent Jr.  Tor  G-F  24.0  34.6  0.430407  0.909000   2.752000
# 10      Kelly Oubre Jr.  Cha  F-G  28.0  29.3  0.463380  0.649000   2.963929
# ...

# %%
df2 = df.loc[[143,316,453,62,414,260,163,83,285,447,128,388,50,152]]
df2
# Out:
#             FULL NAME TEAM  POS  GP   MPG  USG%  FGA       FG%  FTA    FT%  \
# 143      De'Aaron Fox  Sac    G  26  34.8  27.8  455  0.446099  149  0.745
# 316   Dejounte Murray  San    G  24  34.8  26.0  423  0.446721   57  0.702
# 453     Derrick White  San    G  24  31.5  19.8  289  0.414986   60  0.817
# 62      Dillon Brooks  Mem  G-F  12  26.6  30.3  189  0.407037   36  0.917
# 414      Jayson Tatum  Bos  F-G  27  36.3  32.8  587  0.413814  162  0.815
# 260      Caris LeVert  Ind    G  20  28.1  26.5  292  0.428048   43  0.791
# 163    Draymond Green  Gol    F  24  30.3  14.1  140  0.549700   55  0.582
# 83        Alex Caruso  Chi    G  23  28.6  13.5  147  0.441776   49  0.857
# 285      Tyrese Maxey  Phi    G  25  34.7  21.0  333  0.465369   86  0.884
# 447   P.J. Washington  Cha    F  15  25.0  17.4  123  0.455285   23  0.696
# 128   Anthony Edwards  Min    G  26  36.3  27.1  489  0.421209   90  0.778
# ...

# %%
last_row = {'FULL NAME': 'Team Stats', 'FG%': df2['FG%'].mean(), 'FT%': df2['FT%'].mean(), '3P%': df2['3P%'].mean(), 
       '3PPG': df2['3PPG'].sum(), 'PPG': df2['PPG'].sum(), 'RPG': df2['RPG'].sum(),'APG': df2['APG'].sum(), 
       'SPG': df2['SPG'].sum(), 'BPG': df2['BPG'].sum(), 'TO': df2['TO'].sum()}

df2 = df2.append(last_row, ignore_index = True)

df2
# Out:
#            FULL NAME TEAM  POS    GP   MPG  USG%    FGA       FG%    FTA  \
# 0       De'Aaron Fox  Sac    G  26.0  34.8  27.8  455.0  0.446099  149.0
# 1    Dejounte Murray  San    G  24.0  34.8  26.0  423.0  0.446721   57.0
# 2      Derrick White  San    G  24.0  31.5  19.8  289.0  0.414986   60.0
# 3      Dillon Brooks  Mem  G-F  12.0  26.6  30.3  189.0  0.407037   36.0
# 4       Jayson Tatum  Bos  F-G  27.0  36.3  32.8  587.0  0.413814  162.0
# 5       Caris LeVert  Ind    G  20.0  28.1  26.5  292.0  0.428048   43.0
# 6     Draymond Green  Gol    F  24.0  30.3  14.1  140.0  0.549700   55.0
# 7        Alex Caruso  Chi    G  23.0  28.6  13.5  147.0  0.441776   49.0
# 8       Tyrese Maxey  Phi    G  25.0  34.7  21.0  333.0  0.465369   86.0
# 9    P.J. Washington  Cha    F  15.0  25.0  17.4  123.0  0.455285   23.0
# 10   Anthony Edwards  Min    G  26.0  36.3  27.1  489.0  0.421209   90.0
# 11  D'Angelo Russell  Min    G  21.0  32.7  27.3  361.0  0.382626   76.0
# ...

# %%
Shaggy = df2.drop(columns = ['USG%','FGA','FTA','2PA','2P%','2PM','3P%','3PA','3PM','TRB%','DRTG'])
Shaggy
# Out:
#            FULL NAME TEAM  POS    GP   MPG       FG%       FT%       3PPG  \
# 0       De'Aaron Fox  Sac    G  26.0  34.8  0.446099  0.745000   1.152885
# 1    Dejounte Murray  San    G  24.0  34.8  0.446721  0.702000   1.460292
# 2      Derrick White  San    G  24.0  31.5  0.414986  0.817000   1.625000
# 3      Dillon Brooks  Mem  G-F  12.0  26.6  0.407037  0.917000   1.498333
# 4       Jayson Tatum  Bos  F-G  27.0  36.3  0.413814  0.815000   2.700778
# 5       Caris LeVert  Ind    G  20.0  28.1  0.428048  0.791000   1.300500
# 6     Draymond Green  Gol    F  24.0  30.3  0.549700  0.582000   0.291333
# 7        Alex Caruso  Chi    G  23.0  28.6  0.441776  0.857000   0.999000
# 8       Tyrese Maxey  Phi    G  25.0  34.7  0.465369  0.884000   1.080000
# 9    P.J. Washington  Cha    F  15.0  25.0  0.455285  0.696000   2.001067
# 10   Anthony Edwards  Min    G  26.0  36.3  0.421209  0.778000   2.881500
# 11  D'Angelo Russell  Min    G  21.0  32.7  0.382626  0.829000   2.860857
# ...

# %%
Farzan
# Out:
#               FULL NAME TEAM  POS    GP   MPG       FG%       FT%       3PPG  \
# 0        Reggie Jackson  Lac    G  26.0  33.5  0.389144  0.787000   2.733385
# 1            Alec Burks  Nyk    G  26.0  25.3  0.404573  0.816000   1.963269
# 2          Cole Anthony  Orl    G  20.0  34.0  0.428713  0.870000   2.748200
# 3          Bradley Beal  Was    G  23.0  36.0  0.441038  0.848000   1.480870
# 4           Joel Embiid  Phi  C-F  16.0  32.9  0.441088  0.776000   1.311750
# 5           Evan Mobley  Cle    C  23.0  33.4  0.479213  0.783000   0.608087
# 6   Robert Williams III  Bos  C-F  20.0  27.5  0.741000  0.667000   0.000000
# 7       Malcolm Brogdon  Ind    G  23.0  35.5  0.447423  0.874000   1.824000
# 8     Jarred Vanderbilt  Min    F  25.0  23.5  0.535429  0.813000   0.040000
# 9        Gary Trent Jr.  Tor  G-F  24.0  34.6  0.430407  0.909000   2.752000
# 10      Kelly Oubre Jr.  Cha  F-G  28.0  29.3  0.463380  0.649000   2.963929
# ...
